# %%
import pandas as pd

# %%
data = {"coluna_1": [1.5, 2.0, 1.7, 2.2, 1.9],
    "coluna_2": [10.0, 12.0, 11.5, 13.0, 11.0],
    "coluna_3": [0, 1, 0, 1, 0],
    "coluna_4": [1, 0, 1, 1, 0],
    "coluna_5": [20.5, 25.5, 22.0, 27.0, 23.0]}

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#    coluna_1  coluna_2  coluna_3  coluna_4  coluna_5
# 0       1.5      10.0         0         1      20.5
# 1       2.0      12.0         1         0      25.5
# 2       1.7      11.5         0         1      22.0
# 3       2.2      13.0         1         1      27.0
# 4       1.9      11.0         0         0      23.0

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
origem = '/content/drive/My Drive/data/COMEXSTAT/'

# %%
arquivo_1 = origem + 'EXP2024.csv'
arquivo_2 = origem + 'EXP2025.csv'
arquivo_3 = origem + 'EXP2023.csv'
ncm = origem + 'NCM.csv'
pais = origem + 'PAIS.csv'
vias = origem + 'VIA.csv'
urf = origem + 'URF.csv'

# %%
exp24 = pd.read_csv(arquivo_1,low_memory=False,sep=';',encoding='UTF-8')
exp25 = pd.read_csv(arquivo_2,low_memory=False,sep=';',encoding='UTF-8')
# exp23 = pd.read_csv(arquivo_3,low_memory=False,sep=';',encoding='UTF-8')
expncm = pd.read_csv(ncm,low_memory=False,sep=';',encoding='latin1')
exppais = pd.read_csv(pais,low_memory=False,sep=';',encoding='latin1')
expvias = pd.read_csv(vias,low_memory=False,sep=';',encoding='latin1')
expurf = pd.read_csv(urf,low_memory=False,sep=';',encoding='latin1')

# %%
# exp23.info()

# %%
exp24.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1603796 entries, 0 to 1603795
# Data columns (total 11 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   CO_ANO      1603796 non-null  int64
#  1   CO_MES      1603796 non-null  int64
#  2   CO_NCM      1603796 non-null  int64
#  3   CO_UNID     1603796 non-null  int64
#  4   CO_PAIS     1603796 non-null  int64
#  5   SG_UF_NCM   1603796 non-null  object
#  6   CO_VIA      1603796 non-null  int64
#  7   CO_URF      1603796 non-null  int64
#  8   QT_ESTAT    1603796 non-null  int64
#  9   KG_LIQUIDO  1603796 non-null  int64
#  10  VL_FOB      1603796 non-null  int64
# dtypes: int64(10), object(1)
# memory usage: 134.6+ MB

# %%
exp25.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1110202 entries, 0 to 1110201
# Data columns (total 11 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   CO_ANO      1110202 non-null  int64
#  1   CO_MES      1110202 non-null  int64
#  2   CO_NCM      1110202 non-null  int64
#  3   CO_UNID     1110202 non-null  int64
#  4   CO_PAIS     1110202 non-null  int64
#  5   SG_UF_NCM   1110202 non-null  object
#  6   CO_VIA      1110202 non-null  int64
#  7   CO_URF      1110202 non-null  int64
#  8   QT_ESTAT    1110202 non-null  int64
#  9   KG_LIQUIDO  1110202 non-null  int64
#  10  VL_FOB      1110202 non-null  int64
# dtypes: int64(10), object(1)
# memory usage: 93.2+ MB

# %%
expncm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13726 entries, 0 to 13725
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CO_NCM          13726 non-null  int64
#  1   CO_UNID         13726 non-null  int64
#  2   CO_SH6          13726 non-null  int64
#  3   CO_PPE          13423 non-null  float64
#  4   CO_PPI          13423 non-null  float64
#  5   CO_FAT_AGREG    13705 non-null  float64
#  6   CO_CUCI_ITEM    13726 non-null  object
#  7   CO_CGCE_N3      13726 non-null  int64
#  8   CO_SIIT         13423 non-null  float64
#  9   CO_ISIC_CLASSE  13726 non-null  int64
#  10  CO_EXP_SUBSET   13421 non-null  float64
#  11  NO_NCM_POR      13726 non-null  object
#  12  NO_NCM_ESP      13726 non-null  object
#  13  NO_NCM_ING      13726 non-null  object
# dtypes: float64(5), int64(5), object(4)
# memory usage: 1.5+ MB

# %%
exppais.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 281 entries, 0 to 280
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CO_PAIS        281 non-null    int64
#  1   CO_PAIS_ISON3  281 non-null    int64
#  2   CO_PAIS_ISOA3  281 non-null    object
#  3   NO_PAIS        281 non-null    object
#  4   NO_PAIS_ING    281 non-null    object
#  5   NO_PAIS_ESP    281 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 13.3+ KB

# %%
expvias.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CO_VIA  17 non-null     int64
#  1   NO_VIA  17 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 404.0+ bytes

# %%
expurf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CO_URF  280 non-null    int64
#  1   NO_URF  280 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 4.5+ KB

# %%
exp_final = pd.concat([exp24,exp25], ignore_index=True)
exp_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2713998 entries, 0 to 2713997
# Data columns (total 11 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   CO_ANO      int64
#  1   CO_MES      int64
#  2   CO_NCM      int64
#  3   CO_UNID     int64
#  4   CO_PAIS     int64
#  5   SG_UF_NCM   object
#  6   CO_VIA      int64
#  7   CO_URF      int64
#  8   QT_ESTAT    int64
#  9   KG_LIQUIDO  int64
#  10  VL_FOB      int64
# dtypes: int64(10), object(1)
# memory usage: 227.8+ MB

# %%
exp_final.head(5)
# Out:
#    CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  CO_URF  \
# 0    2024       4  94036000       11      245        SP       4  817600
# 1    2024      11  87088000       11      493        SP       1  817800
# 2    2024       3   2071400       10      173        SP       1  817800
# 3    2024       4  90303390       11      158        MG       1  817800
# 4    2024       8  40129090       10      158        SC       4  817700
#
#    QT_ESTAT  KG_LIQUIDO  VL_FOB
# 0         8         425   20423
# 1    418615       60355  470512
# 2     94080       94080  237562
# 3        10          12    1704
# 4        26          26     950

# %%
exp_final.tail(5)
# Out:
#          CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  CO_URF  \
# 2713993    2025       6   9021000       10      434        PA       0  210200
# 2713994    2025       5  63026000       10      580        SC       1  927800
# 2713995    2025       2  27101922       16       83        RJ       1  717600
# 2713996    2025       2  20098990       10      301        RJ       1  727600
# 2713997    2025       2  61062000       11      607        SC       4  817700
#
#          QT_ESTAT  KG_LIQUIDO  VL_FOB
# 2713993         6           6       6
# 2713994       126         126    1005
# 2713995       413      380022  237224
# 2713996         3           3       7
# 2713997        57          17     496

# %%
exppais.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 281 entries, 0 to 280
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CO_PAIS        281 non-null    int64
#  1   CO_PAIS_ISON3  281 non-null    int64
#  2   CO_PAIS_ISOA3  281 non-null    object
#  3   NO_PAIS        281 non-null    object
#  4   NO_PAIS_ING    281 non-null    object
#  5   NO_PAIS_ESP    281 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 13.3+ KB

# %%
exp_final = exp_final.merge(exppais[['CO_PAIS','NO_PAIS']],on='CO_PAIS',how='left')

# %%
exp_final.head(5)
# Out:
#    CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  CO_URF  \
# 0    2024       4  94036000       11      245        SP       4  817600
# 1    2024      11  87088000       11      493        SP       1  817800
# 2    2024       3   2071400       10      173        SP       1  817800
# 3    2024       4  90303390       11      158        MG       1  817800
# 4    2024       8  40129090       10      158        SC       4  817700
#
#    QT_ESTAT  KG_LIQUIDO  VL_FOB  NO_PAIS
# 0         8         425   20423  Espanha
# 1    418615       60355  470512   México
# 2     94080       94080  237562  Comores
# 3        10          12    1704    Chile
# 4        26          26     950    Chile

# %%
exp_final.tail(5)
# Out:
#          CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  CO_URF  \
# 2713993    2025       6   9021000       10      434        PA       0  210200
# 2713994    2025       5  63026000       10      580        SC       1  927800
# 2713995    2025       2  27101922       16       83        RJ       1  717600
# 2713996    2025       2  20098990       10      301        RJ       1  727600
# 2713997    2025       2  61062000       11      607        SC       4  817700
#
#          QT_ESTAT  KG_LIQUIDO  VL_FOB   NO_PAIS
# 2713993         6           6       6   Libéria
# 2713994       126         126    1005    Panamá
# 2713995       413      380022  237224  Barbados
# 2713996         3           3       7    Grécia
# 2713997        57          17     496  Portugal

# %%
exp_final = exp_final.merge(expncm[['CO_NCM','NO_NCM_POR']],on='CO_NCM',how='left')

# %%
exp_final
# Out:
#          CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  CO_URF  \
# 0          2024       4  94036000       11      245        SP       4  817600
# 1          2024      11  87088000       11      493        SP       1  817800
# 2          2024       3   2071400       10      173        SP       1  817800
# 3          2024       4  90303390       11      158        MG       1  817800
# 4          2024       8  40129090       10      158        SC       4  817700
# ...         ...     ...       ...      ...      ...       ...     ...     ...
# 2713993    2025       6   9021000       10      434        PA       0  210200
# 2713994    2025       5  63026000       10      580        SC       1  927800
# 2713995    2025       2  27101922       16       83        RJ       1  717600
# 2713996    2025       2  20098990       10      301        RJ       1  727600
# 2713997    2025       2  61062000       11      607        SC       4  817700
#
#          QT_ESTAT  KG_LIQUIDO  VL_FOB   NO_PAIS  \
# 0               8         425   20423   Espanha
# 1          418615       60355  470512    México
# 2           94080       94080  237562   Comores
# 3              10          12    1704     Chile
# 4              26          26     950     Chile
# ...           ...         ...     ...       ...
# 2713993         6           6       6   Libéria
# 2713994       126         126    1005    Panamá
# 2713995       413      380022  237224  Barbados
# 2713996         3           3       7    Grécia
# 2713997        57          17     496  Portugal
#
#                                                 NO_NCM_POR
# 0                                 Outros móveis de madeira
# 1        Amortecedores de suspensão para tratores e veí...
# 2        Pedaços e miudezas, comestíveis de galos/galin...
# 3        Outros aparelhos e instrumentos sem dispositiv...
# 4        Protetores, bandas de rodagem, etc, para pneus...
# ...                                                    ...
# 2713993  Chá verde (não fermentado) em embalagens imedi...
# 2713994  Roupas de toucador ou de cozinha, de tecidos a...
# 2713995                                           Fuel oil
# 2713996  Sucos (sumo) de outras frutas, não fermentado,...
# 2713997  Camisas, blusas, blusas chemisiers, de malha, ...
#
# [2713998 rows x 13 columns]
# Warning: total number of rows (2713998) exceeds max_rows (20000). Limiting to first (20000) rows.

# %%
coluna = 'NO_PAIS'
CP = exp_final[coluna].value_counts().sort_values(ascending=False)
print(f'total de operações {coluna}:')
print(CP)
# Out:
# total de operações NO_PAIS:
# NO_PAIS
# Paraguai                     173678
# Estados Unidos               167074
# Argentina                    163535
# Panamá                       118718
# Uruguai                      117480
#                               ...
# Saara Ocidental                   2
# Christmas (Navidad), Ilha         2
# São Pedro e Miquelon              1
# Santa Helena                      1
# Coreia do Norte                   1
# Name: count, Length: 247, dtype: int64

# %%
exp_final.to_csv(origem+'exp_final.csv', index=False)
